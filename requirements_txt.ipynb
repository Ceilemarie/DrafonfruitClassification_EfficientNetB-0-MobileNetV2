# %%
import os

# %%
# Content for requirements.txt based on the project environment
requirements_content = """
tensorflow>=2.15.0
keras>=2.15.0
numpy>=1.23.5
pandas>=1.5.3
matplotlib>=3.7.1
seaborn>=0.12.2
scikit-learn>=1.2.2
opencv-python>=4.8.0
pillow>=9.4.0
"""

# %%
# Define the filename
file_path = 'requirements.txt'

# Write the content to the file
with open(file_path, 'w') as f:
    f.write(requirements_content.strip())

print(f"File '{file_path}' has been successfully created.")
# Out:
# File 'requirements.txt' has been successfully created.
